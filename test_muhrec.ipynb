# %%
import numpy as np
import sys
import os

# Add the directory containing 'mymodule.py' to sys.path
sys.path.append(os.path.abspath('/dtu-compute/msaca/muhrec_folder/imagingsuite/package/pymuhrec/'))

# %%
import pymuhrec

# %%
import numpy as np
import matplotlib.pyplot as plt
import imgalg as ia
import muhrectomo as mt
import amglib.readers as io
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 5
#       3 import imgalg as ia
#       4 import muhrectomo as mt
# ----> 5 import amglib.readers as io
#
# ModuleNotFoundError: No module named 'amglib'

# %%
recon = mt.Reconstructor(mt.bpMultiProj)
recon.name()
# Out:
# [message] Multi projection BP -- C'tor BackProjBase
# [message] Multi projection BP -- c'tor StdBackProjectorBase
# [message] Multi projection BP -- C'tor MultiProjectionBP
# 'Multi projection BP'

# %%
ob = np.ones((100,100))
dc = np.ones((100,100))
normalize = ia.NormalizeImage(True)
spotclean = ia.MorphSpotClean()
ringclean = ia.StripeFilter([100,100],"daub11",3,0.05) # sinogram dims are temporarily set to 100x100
normalize.setDoseROI([10,10,50,50])
normalize.setReferences(ob,dc)

# %%
img = np.zeros((100,100))
plt.subplot(1,2,1); plt.imshow(img)
normalize.process(img)
plt.subplot(1,2,2); plt.imshow(img)
