# %%
import numpy as np
import matplotlib.pyplot as plt
import os
os.chdir('/zhome/71/c/146676/main/')
import SimpleITK as sitk
from loaders import loader_XA_to_NA
import importlib
importlib.reload(loader_XA_to_NA)
import tifffile
import nibabel as nib

# %%
reg = loader_XA_to_NA.load_registered_data(compression = 1, dataset_XA='tv', dataset_NA='dtv')
# Out:
# Resampling the transformation
# Resampling moving image

# %%
reg_fbp = loader_XA_to_NA.load_registered_data(compression = 1, dataset_XA= 'tv', dataset_NA='fbp')
# Out:
# Resampling the transformation
# Resampling moving image

# %%
#NA = sitk.GetArrayFromImage(reg.fixed)
#affine = np.eye(4)
#nii_NA = nib.Nifti1Image(NA, affine)
#nib.save(nii_NA, "/dtu-compute/msaca/sliceA_neutron_psi/output/dtv_recon/NA_dtv.nii")

# %%
#NA = sitk.GetArrayFromImage(reg.fixed)[::2,::2,::2]
#affine = np.eye(4)
#nii_NA = nib.Nifti1Image(NA, affine)
#nib.save(nii_NA, "/dtu-compute/msaca/sliceA_neutron_psi/output/dtv_recon/NA_dtv_comp_x2.nii")

# %%
#NA = sitk.GetArrayFromImage(reg_fbp.fixed)[::2,::2,::2]
#affine = np.eye(4)
#nii_NA = nib.Nifti1Image(NA, affine)
#nib.save(nii_NA, "/dtu-compute/msaca/sliceA_neutron_psi/output/fbp_recon/NA_fbp_comp_x2.nii")

# %%
#XA = sitk.GetArrayFromImage(reg.moving)
#affine = np.eye(4)
#nii_XA = nib.Nifti1Image(XA, affine)
#nib.save(nii_XA, "/dtu-compute/msaca/sliceA_xray_pc/output/tv_recon/XA_tv.nii")

# %%
#XA = sitk.GetArrayFromImage(reg.moving)[::2,::2,::2]
#affine = np.eye(4)
#nii_XA = nib.Nifti1Image(XA, affine)
#nib.save(nii_XA, "/dtu-compute/msaca/sliceA_xray_pc/output/tv_recon/XA_tv_comp_x2.nii")

# %%
plt.figure(figsize=(8,8))
plt.imshow(reg.as_array(reg.fixed)[700])
plt.clim([-0.02,0.1])
plt.show()

plt.figure(figsize=(8,8))
plt.imshow(reg.as_array(reg.moving)[700])
plt.clim([-0.02,0.1])
plt.show()

plt.figure(figsize=(8,8))
plt.imshow((reg.as_array(reg.moving)[700]>0.02)*1.0 - (reg.as_array(reg.fixed)[700]>0.02)*1.0)
plt.show()


fig, axes = plt.subplots(1, 3, figsize=(20, 6.67))  # 1 row, 3 columns
fig.patch.set_facecolor('black')  # Set the background color to black
clims = [(-0.02, 0.08), (-0.02, 0.08), (-1, 1)]
im1 = axes[0].imshow(reg.as_array(reg.fixed)[:,200], cmap='viridis', vmin=clims[0][0], vmax=clims[0][1])
axes[0].axis('off')
im2 = axes[1].imshow(reg.as_array(reg.moving)[:,200], cmap='viridis', vmin=clims[1][0], vmax=clims[1][1])
axes[1].axis('off')
im3 = axes[2].imshow((reg.as_array(reg.fixed)[:,200]<0.02)*1.0 - (reg.as_array(reg.moving)[:,200]<0.02)*1.0,
                        cmap='viridis', vmin=clims[2][0], vmax=clims[2][1])
axes[2].axis('off')
plt.subplots_adjust(wspace=0.1)
plt.show()


fig, axes = plt.subplots(1, 3, figsize=(20, 6.67))  # 1 row, 3 columns
fig.patch.set_facecolor('black')  # Set the background color to black
clims = [(-0.02, 0.08), (-0.02, 0.08), (-1, 1)]
im1 = axes[0].imshow(reg.as_array(reg.fixed)[:,:,1000], cmap='viridis', vmin=clims[0][0], vmax=clims[0][1])
axes[0].axis('off')
im2 = axes[1].imshow(reg.as_array(reg.moving)[:,:,1000], cmap='viridis', vmin=clims[1][0], vmax=clims[1][1])
axes[1].axis('off')
im1 = axes[2].imshow((reg.as_array(reg.fixed)[:,:,1000]<0.02)*1.0 - (reg.as_array(reg.moving)[:,:,1000]<0.02)*1.0,
                        cmap='viridis', vmin=clims[2][0], vmax=clims[2][1])
axes[2].axis('off')
plt.subplots_adjust(wspace=-0.9)
plt.show()


fig, axes = plt.subplots(1, 2, figsize=(14, 6.67))  # 1 row, 3 columns
fig.patch.set_facecolor('black')  # Set the background color to black
clims = [(-0.02, 0.08), (-0.02, 0.08), (-1, 1)]
im1 = axes[0].imshow(reg.as_array(reg.fixed)[700,100:200,700:800], cmap='viridis', vmin=clims[0][0], vmax=clims[0][1])
axes[0].axis('off')
im2 = axes[1].imshow(reg.as_array(reg.moving)[700,100:200,700:800], cmap='viridis', vmin=clims[1][0], vmax=clims[1][1])
axes[1].axis('off')
plt.subplots_adjust(wspace=0.1)
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.imshow(reg_fbp.as_array(reg_fbp.fixed)[700])
plt.clim([-0.02,0.1])
plt.show()

plt.figure(figsize=(8,8))
plt.imshow(reg_fbp.as_array(reg_fbp.moving)[700])
plt.clim([-0.02,0.1])
plt.show()

plt.figure(figsize=(8,8))
plt.imshow((reg_fbp.as_array(reg_fbp.moving)[700]>0.02)*1.0 - (reg_fbp.as_array(reg_fbp.fixed)[700]>0.02)*1.0)
plt.show()


fig, axes = plt.subplots(1, 3, figsize=(20, 6.67))  # 1 row, 3 columns
fig.patch.set_facecolor('black')  # Set the background color to black
clims = [(-0.02, 0.08), (-0.02, 0.08), (-1, 1)]
im1 = axes[0].imshow(reg_fbp.as_array(reg_fbp.fixed)[:,200], cmap='viridis', vmin=clims[0][0], vmax=clims[0][1])
axes[0].axis('off')
im2 = axes[1].imshow(reg_fbp.as_array(reg_fbp.moving)[:,200], cmap='viridis', vmin=clims[1][0], vmax=clims[1][1])
axes[1].axis('off')
im3 = axes[2].imshow((reg_fbp.as_array(reg_fbp.fixed)[:,200]<0.02)*1.0 - (reg_fbp.as_array(reg_fbp.moving)[:,200]<0.02)*1.0,
                        cmap='viridis', vmin=clims[2][0], vmax=clims[2][1])
axes[2].axis('off')
plt.subplots_adjust(wspace=0.1)
plt.show()


fig, axes = plt.subplots(1, 3, figsize=(20, 6.67))  # 1 row, 3 columns
fig.patch.set_facecolor('black')  # Set the background color to black
clims = [(-0.02, 0.08), (-0.02, 0.08), (-1, 1)]
im1 = axes[0].imshow(reg_fbp.as_array(reg_fbp.fixed)[:,:,1000], cmap='viridis', vmin=clims[0][0], vmax=clims[0][1])
axes[0].axis('off')
im2 = axes[1].imshow(reg_fbp.as_array(reg_fbp.moving)[:,:,1000], cmap='viridis', vmin=clims[1][0], vmax=clims[1][1])
axes[1].axis('off')
im1 = axes[2].imshow((reg_fbp.as_array(reg_fbp.fixed)[:,:,1000]<0.02)*1.0 - (reg_fbp.as_array(reg_fbp.moving)[:,:,1000]<0.02)*1.0,
                        cmap='viridis', vmin=clims[2][0], vmax=clims[2][1])
axes[2].axis('off')
plt.subplots_adjust(wspace=-0.9)
plt.show()


fig, axes = plt.subplots(1, 2, figsize=(14, 6.67))  # 1 row, 3 columns
fig.patch.set_facecolor('black')  # Set the background color to black
clims = [(-0.02, 0.08), (-0.02, 0.08), (-1, 1)]
im1 = axes[0].imshow(reg_fbp.as_array(reg_fbp.fixed)[700,100:200,700:800], cmap='viridis', vmin=clims[0][0], vmax=clims[0][1])
axes[0].axis('off')
im2 = axes[1].imshow(reg_fbp.as_array(reg_fbp.moving)[700,100:200,700:800], cmap='viridis', vmin=clims[1][0], vmax=clims[1][1])
axes[1].axis('off')
plt.subplots_adjust(wspace=0.1)
plt.show()

# %%
threshold = [0.014, 0.014]
factor = 4
reg.compute_stone_boundaries(thresholds = threshold, factor = factor) # saved in reg.fixed_seg and reg.moving_seg
initial_mask = reg.fixed_seg
mask = sitk.Resample(
    initial_mask,
    reg.fixed,
    sitk.Transform(),
    sitk.sitkNearestNeighbor,  # Use nearest neighbor to preserve binary mask values
    initial_mask.GetPixelID()
)

mask = reg.as_array(mask)
fixed = reg.as_array(reg.fixed)
moving = reg.as_array(reg.moving)
plt.imshow(1*mask[:,200,:])

# %%
threshold = [0.014, 0.014]
factor = 2
reg_fbp.compute_stone_boundaries(thresholds = threshold, factor = factor) # saved in reg.fixed_seg and reg.moving_seg
initial_mask = reg_fbp.fixed_seg
mask_fbp = sitk.Resample(
    initial_mask,
    reg_fbp.fixed,
    sitk.Transform(),
    sitk.sitkNearestNeighbor,  # Use nearest neighbor to preserve binary mask values
    initial_mask.GetPixelID()
)

mask_fbp = reg_fbp.as_array(mask_fbp)
fixed_fbp = reg_fbp.as_array(reg_fbp.fixed)
moving_fbp = reg_fbp.as_array(reg_fbp.moving)
plt.imshow(1*mask_fbp[:,200,:])

# %%
sampling_rate = 1
shape = np.shape(mask)
random_mask = np.random.rand(*shape) < sampling_rate
plt.imshow(1*mask[:,200,:])
mask = mask*random_mask*(fixed>0.0001)*np.logical_or(moving < -0.00001, moving > 0.00001)
mask = mask.astype(bool)


fixed_values = fixed[mask]
moving_values = moving[mask]

# %%
sampling_rate = 1
shape = np.shape(mask_fbp)
random_mask_fbp = np.random.rand(*shape) < sampling_rate
plt.imshow(1*mask_fbp[:,200,:])
mask_fbp = mask_fbp*random_mask_fbp*(fixed_fbp>0.0001)*np.logical_or(moving_fbp < -0.00001, moving_fbp > 0.00001)
mask_fbp = mask_fbp.astype(bool)


fixed_values_fbp = fixed_fbp[mask_fbp]
moving_values_fbp = moving_fbp[mask_fbp]

# %%
import matplotlib.cm as cm
import matplotlib.colors as mcolors

def add_squares(x, y):
  
    """
    Add squares to an existing figure based on specified intervals, with automatic color assignment.
    
    Parameters:
    - x: List of intervals for the x-axis, e.g., [[x1_s, x1_e], [x2_s, x2_e], ...].
    - y: List of intervals for the y-axis, e.g., [[y1_s, y1_e], [y2_s, y2_e], ...].
    - cmap: Matplotlib colormap for generating colors (default: "tab10").
    - linewidth: Thickness of the square outlines (default: 2).

    Returns:
    - colors: List of colors assigned to each square.
    """
    cmap = "tab10"
    if len(x) != len(y):
        raise ValueError("The number of x-intervals and y-intervals must be the same.")
    
    ax = plt.gca()  # Get the current axes
    num_squares = len(x)
    colors = cm.get_cmap(cmap, num_squares).colors  # Generate distinct colors from the colormap
    
    for i, (x_interval, y_interval) in enumerate(zip(x, y)):
        # Ensure intervals are valid
        if len(x_interval) != 2 or len(y_interval) != 2:
            raise ValueError("Each interval must have exactly two elements: [start, end].")
        
        # Add a rectangle for each interval pair
        rectangle = plt.Rectangle(
            (x_interval[0], y_interval[0]),  # Bottom-left corner
            x_interval[1] - x_interval[0],  # Width
            y_interval[1] - y_interval[0],  # Height
            edgecolor=colors[i],
            facecolor="none",
            linewidth=2,
        )
        ax.add_patch(rectangle)

    colormaps = []
    for i, color in enumerate(colors):
        # Define the color map
        name_prefix = "custom"
        factor = 1.5
        cmap = mcolors.LinearSegmentedColormap.from_list(
            f"{name_prefix}_{i}",
            [(0, 0, 0), color]  # Transition from black to the given color
        )
        cdict = cmap._segmentdata
        # Modify the colors (this is done for each color channel: red, green, blue)
        for channel in ['red', 'green', 'blue']:
            # Scale each color in the channel towards 1 (white)
            for i, (t, c1, c2) in enumerate(cdict[channel]):
                new_c1 = min(c1 * factor, 1.0)
                new_c2 = min(c2 * factor, 1.0)
                cdict[channel][i] = (t, new_c1, new_c2)
        b_cmap = mcolors.LinearSegmentedColormap(cmap.name + '_brightened', segmentdata=cdict)
        colormaps.append(b_cmap)
    return colormaps

# %%
def heatmap(fixed_values, moving_values,neutron=None, xray = None):
    bins = 400
    nticks = 15
    range_fixed = [-0.01, 0.11]
    range_moving = [-0.01, 0.11]

    # Create the heatmap
    heatmap, xedges, yedges = np.histogram2d(
        fixed_values, moving_values, bins=(bins, bins),
        range=[range_fixed, range_moving]
    )
    log_heatmap = np.log1p(heatmap)

    # Plot the heatmap
    plt.figure(figsize=(10, 10))
    plt.imshow(
        log_heatmap.T, origin="lower", aspect="auto", cmap="YlGnBu",
        extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]]  # Set extent to match data range
    )
    plt.colorbar(label="log-Frequency")
    plt.xlabel("Fixed: Neutron")
    plt.ylabel("Moving: Xray")
    plt.title("Heatmap with Highlighted Square")

    # Set custom ticks
    x_tick_positions = np.linspace(xedges[0], xedges[-1], num=nticks)
    y_tick_positions = np.linspace(yedges[0], yedges[-1], num=nticks)
    x_tick_labels = [f"{x:.3f}" for x in x_tick_positions]
    y_tick_labels = [f"{y:.3f}" for y in y_tick_positions]
    plt.xticks(x_tick_positions, x_tick_labels)
    plt.yticks(y_tick_positions, y_tick_labels)

    if neutron is not None:
        colors = add_squares(x=neutron, y=xray)
    # Show the plot
    plt.show()
    if neutron is not None:
        return colors

# %%
neutron = [[0, 0.04], [0,0.04], [0.04, 0.1], [0.01, 0.06], [0,0.005]]
xray = [[0.01,0.025], [0, 00.01], [-0.01, 0.11], [0.05, 0.1], [-0.01, 0.11]]
colors = heatmap(fixed_values, moving_values,neutron=neutron, xray = xray)
# Out:
# /tmp/pbs.499807.hnode41/ipykernel_1100540/1731157786.py:24: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap(cmap, num_squares).colors  # Generate distinct colors from the colormap

# %%
neutron = [[0, 0.04], [0,0.04], [0.05, 0.1], [0.01, 0.06], [0,0.005]]
xray = [[0.01,0.025], [0, 00.01], [0, 0.09], [0.05, 0.1], [0, 0.1]]
colors = heatmap(fixed_values_fbp, moving_values_fbp,neutron=neutron, xray = xray)
# Out:
# /tmp/pbs.499807.hnode41/ipykernel_1100540/1731157786.py:24: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap(cmap, num_squares).colors  # Generate distinct colors from the colormap

# %%
def display_segmentation(neutron_values, xray_values, neutron_intervals, xray_intervals):
    num_plots = len(xray_intervals)  # Adjust this for the number of plots you want
    plots_per_row = 3

    # Calculate the number of rows needed
    num_rows = (num_plots + plots_per_row - 1) // plots_per_row  # Ceiling division

    # Create the figure with subplots
    fig, axes = plt.subplots(num_rows, plots_per_row, figsize=(22.5, 7.5 * num_rows))  # Adjust figure size as needed
    axes = axes.flatten()  # Flatten the axes array for easier indexing
    # Set the figure background to black
    fig.patch.set_facecolor('black')

    # Loop through each plot
    for i in range(num_plots):
        ax = axes[i]
        segm = mask*np.logical_and(neutron_values>neutron_intervals[i][0],neutron_values<neutron_intervals[i][1])*np.logical_and(xray_values>xray_intervals[i][0],xray_values<xray_intervals[i][1])
        proj_segm = np.sum(segm,axis=1)/np.shape(segm)[1]
        ax.imshow(proj_segm, cmap = colors[i])
        # Remove axes and set background color to black
        ax.axis('off')
        ax.set_facecolor('black')  # Set subplot background color

    # Hide any extra subplots if num_plots is not a multiple of plots_per_row
    for j in range(num_plots, len(axes)):
        fig.delaxes(axes[j])

# %%
display_segmentation(neutron_values = fixed, xray_values = moving, neutron_intervals = neutron, xray_intervals = xray)

# %%
display_segmentation(neutron_values = fixed_fbp, xray_values = moving_fbp, neutron_intervals = neutron, xray_intervals = xray)

# %%
# Apply gaussian filtering before making the heatmap
fixed_filtered_ = sitk.SmoothingRecursiveGaussian(reg.fixed, sigma=0.002)
moving_filtered_ = sitk.SmoothingRecursiveGaussian(reg.moving, sigma=0.002)
fixed_filtered = reg.as_array(fixed_filtered_)
moving_filtered = reg.as_array(moving_filtered_)
fixed_values = fixed_filtered[mask]
moving_values = moving_filtered[mask]

xray = [[0.016,0.02], [-0.016, 0.016], [0.02, 0.03], [0.03,0.04],[0.035, 0.1], [0.03,0.04] ]
neutron = [[0, 0.03], [0,0.01], [0,0.025], [0,0.025],[0.025,0.09], [0.035,0.065]]
colors = heatmap(fixed_values, moving_values,neutron=neutron, xray = xray)
# Out:
# /tmp/pbs.499807.hnode41/ipykernel_1100540/1731157786.py:24: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap(cmap, num_squares).colors  # Generate distinct colors from the colormap

# %%
display_segmentation(neutron_values = fixed_filtered, xray_values = moving_filtered, neutron_intervals = neutron, xray_intervals = xray)

# %%
xray = [[0.016,0.02], [-0.016, 0.016], [0.02, 0.03], [0.03,0.04],[0.035, 0.1], [0.03,0.04] ]
neutron = [[0, 0.03], [0,0.01], [0,0.025], [0,0.025],[0.025,0.09], [0.035,0.065]]
neutron_values = fixed_filtered
xray_values = moving_filtered
i = 4
segm = mask*np.logical_and(neutron_values>neutron[i][0],neutron_values<neutron[i][1])*np.logical_and(xray_values>xray[i][0],xray_values<xray[i][1])
SEG = (segm)[::2,::2,::2]*1.0
SEG = np.transpose(SEG, (2, 1, 0))  # Swap axis 0 and 2
affine = np.eye(4)
nii_SEG = nib.Nifti1Image(SEG, affine)
nib.save(nii_SEG, "/dtu-compute/msaca/visualizations/SEG_high_NA_high_XA_x2.nii")

# %%
x0 = 500
x1 = 600
y0 = 150
y1 = 151
z0 = 800
z1 = 900

fig, axes = plt.subplots(5, 2, figsize=(10, 25))  # 1 row, 3 columns
fig.patch.set_facecolor('black')  # Set the background color to black
clims = [(-0.02, 0.08), (-0.02, 0.08), (-1, 1)]
im1 = axes[0,0].imshow(np.squeeze(reg.as_array(reg.fixed)[x0:x1,y0:y1, z0:z1]), cmap='viridis', vmin=clims[0][0], vmax=clims[0][1])
axes[0,0].axis('off')
im2 = axes[0,1].imshow(np.squeeze(reg.as_array(reg.moving)[x0:x1,y0:y1, z0:z1]), cmap='viridis', vmin=clims[1][0], vmax=clims[1][1])
axes[0,1].axis('off')

i = 0

image = mask[x0:x1,y0:y1, z0:z1]*np.logical_and(fixed[x0:x1,y0:y1, z0:z1]>neutron[i][0],
    fixed[x0:x1,y0:y1, z0:z1]<neutron[i][1])*np.logical_and(moving[x0:x1,y0:y1, z0:z1]>xray[i][0],moving[x0:x1,y0:y1, z0:z1]<xray[i][1])
im3 = axes[1,0].imshow(np.squeeze(image), cmap = colors[i], vmin=clims[1][0], vmax=clims[1][1])
axes[1,0].axis('off')

image = mask[x0:x1,y0:y1, z0:z1]*np.logical_and(fixed_filtered[x0:x1,y0:y1, z0:z1]>neutron[i][0],
    fixed_filtered[x0:x1,y0:y1, z0:z1]<neutron[i][1])*np.logical_and(moving_filtered[x0:x1,y0:y1, z0:z1]>xray[i][0],moving_filtered[x0:x1,y0:y1, z0:z1]<xray[i][1])
im3 = axes[1,1].imshow(np.squeeze(image), cmap = colors[i], vmin=clims[1][0], vmax=clims[1][1])
axes[1,1].axis('off')



i = 2
image = mask[x0:x1,y0:y1, z0:z1]*np.logical_and(fixed[x0:x1,y0:y1, z0:z1]>neutron[i][0],
    fixed[x0:x1,y0:y1, z0:z1]<neutron[i][1])*np.logical_and(moving[x0:x1,y0:y1, z0:z1]>xray[i][0],moving[x0:x1,y0:y1, z0:z1]<xray[i][1])
im3 = axes[2,0].imshow(np.squeeze(image), cmap = colors[i], vmin=clims[1][0], vmax=clims[1][1])
axes[2,0].axis('off')

image = mask[x0:x1,y0:y1, z0:z1]*np.logical_and(fixed_filtered[x0:x1,y0:y1, z0:z1]>neutron[i][0],
    fixed_filtered[x0:x1,y0:y1, z0:z1]<neutron[i][1])*np.logical_and(moving_filtered[x0:x1,y0:y1, z0:z1]>xray[i][0],moving_filtered[x0:x1,y0:y1, z0:z1]<xray[i][1])
im3 = axes[2,1].imshow(np.squeeze(image), cmap = colors[i], vmin=clims[1][0], vmax=clims[1][1])
axes[2,1].axis('off')



i = 3
image = mask[x0:x1,y0:y1, z0:z1]*np.logical_and(fixed[x0:x1,y0:y1, z0:z1]>neutron[i][0],
    fixed[x0:x1,y0:y1, z0:z1]<neutron[i][1])*np.logical_and(moving[x0:x1,y0:y1, z0:z1]>xray[i][0],moving[x0:x1,y0:y1, z0:z1]<xray[i][1])
im3 = axes[3,0].imshow(np.squeeze(image), cmap = colors[i], vmin=clims[1][0], vmax=clims[1][1])
axes[3,0].axis('off')

image = mask[x0:x1,y0:y1, z0:z1]*np.logical_and(fixed_filtered[x0:x1,y0:y1, z0:z1]>neutron[i][0],
    fixed_filtered[x0:x1,y0:y1, z0:z1]<neutron[i][1])*np.logical_and(moving_filtered[x0:x1,y0:y1, z0:z1]>xray[i][0],moving_filtered[x0:x1,y0:y1, z0:z1]<xray[i][1])
im3 = axes[3,1].imshow(np.squeeze(image), cmap = colors[i], vmin=clims[1][0], vmax=clims[1][1])
axes[3,1].axis('off')


i = 4
image = mask[x0:x1,y0:y1, z0:z1]*np.logical_and(fixed[x0:x1,y0:y1, z0:z1]>neutron[i][0],
    fixed[x0:x1,y0:y1, z0:z1]<neutron[i][1])*np.logical_and(moving[x0:x1,y0:y1, z0:z1]>xray[i][0],moving[x0:x1,y0:y1, z0:z1]<xray[i][1])
im3 = axes[4,0].imshow(np.squeeze(image), cmap = colors[i], vmin=clims[1][0], vmax=clims[1][1])
axes[4,0].axis('off')

image = mask[x0:x1,y0:y1, z0:z1]*np.logical_and(fixed_filtered[x0:x1,y0:y1, z0:z1]>neutron[i][0],
    fixed_filtered[x0:x1,y0:y1, z0:z1]<neutron[i][1])*np.logical_and(moving_filtered[x0:x1,y0:y1, z0:z1]>xray[i][0],moving_filtered[x0:x1,y0:y1, z0:z1]<xray[i][1])
im3 = axes[4,1].imshow(np.squeeze(image), cmap = colors[i], vmin=clims[1][0], vmax=clims[1][1])
axes[4,1].axis('off')


plt.subplots_adjust(wspace=0.1)
plt.show()

# %%
im_subset = moving[:,150:160,:700]
nz, ny, nx = np.shape(im_subset)
from cil.framework import ImageGeometry, ImageData
from cil.optimisation.operators import GradientOperator
ig = ImageGeometry(voxel_num_x=nx, voxel_num_y=ny, voxel_num_z=nz)
im_subset_ID = ImageData(im_subset, geometry=ig)
def xi_vector_field(image,eta):
    G = GradientOperator(ig)
    numerator = G.direct(image)
    denominator = np.sqrt(eta**2 + numerator.get_item(0)**2 + numerator.get_item(1)**2)
    xi = numerator/denominator

    return (xi.get_item(0)**2 + xi.get_item(1)**2).sqrt()
