# %%
import shutil

# Define paths
hpc_path = "/dtu-compute/msaca/sliceA_diffraction/DA_cache"
local_path = "/home/msaca/Data/sliceA_diffraction/non-integrated"

# Copy a file from HPC to external drive
shutil.copy(f"{hpc_path}/scan-0339_pilatus.h5", f"{local_path}/scan-0339_pilatus.h5")
#shutil.copy(f"{hpc_path}/scan-0339_pilatus.h5", f"{local_path}/scan-0339_pilatus.h5")

# Move instead of copy (saves space on HPC)
#shutil.move(f"{hpc_path}/result_1.bin", f"{local_path}/result_1.bin")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 8
#       5 local_path = "/home/msaca/Data/sliceA_diffraction/non-integrated"
#       7 # Copy a file from HPC to external drive
# ----> 8 shutil.copy(f"{local_path}/scan-0339_pilatus.h5", f"{hpc_path}/scan-0339_pilatus.h5")
#       9 #shutil.copy(f"{hpc_path}/scan-0339_pilatus.h5", f"{local_path}/scan-0339_pilatus.h5")
#      10
#      11 # Move instead of copy (saves space on HPC)
#      12 #shutil.move(f"{hpc_path}/result_1.bin", f"{local_path}/result_1.bin")
#
# File ~/miniconda3/envs/cil5/lib/python3.10/shutil.py:417, in copy(src, dst, follow_symlinks)
#     415 if os.path.isdir(dst):
#     416     dst = os.path.join(dst, os.path.basename(src))
# --> 417 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     418 copymode(src, dst, follow_symlinks=follow_symlinks)
#     419 return dst
#
# ...
