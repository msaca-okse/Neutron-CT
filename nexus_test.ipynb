# %%
import h5py

# Open the .nx file
prefix = '/dtu-compute/msaca/sliceA_xray_pc/'
file_path = 'HA900_3um_mars_rock_001_.nx'
total_path = prefix + file_path
with h5py.File(total_path, 'r') as f:
    # Explore the structure of the file
    print("File structure:")
    f.visit(print)
    
    # Access a specific dataset (update the path as per your file structure)
    dataset = f['/entry/data/array']  # Example path in the NeXus file
    print("\nDataset shape:", dataset.shape)
    print("Dataset dtype:", dataset.dtype)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       4 prefix = '/dtu-compute/msaca/sliceA_xray_pc'
#       5 file_path = 'HA900_3um_mars_rock_001_.nx'
# ----> 6 with h5py.File(file_path, 'r') as f:
#       7     # Explore the structure of the file
#       8     print("File structure:")
#       9     f.visit(print)
#
# File ~/miniconda3/envs/cil5/lib/python3.10/site-packages/h5py/_hl/files.py:561, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     552     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     553                      locking, page_buf_size, min_meta_keep, min_raw_keep,
# ...
